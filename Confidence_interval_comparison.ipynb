# %% [markdown]
# <a href="https://colab.research.google.com/github/PuruBhatnagar1197/ABtesting/blob/main/Confidence_interval_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### here we are trying to compare how normal distribution pdf and beta distribution just get to the same distribution as "#" of trials increases

# %%
import pandas as pd
import numpy as np
from scipy.stats import beta, norm
import matplotlib.pyplot as plt

# %%
T=501
data=np.empty(T)
true_ctr=0.5
a=1
b=1
points_to_plot=[10,20,30,50,100,250,500]

# %%
for i in range(T):
    x=1 if np.random.random()<true_ctr else 0
    data[i]=x
    a+=x
    b+=1-x
    if i in points_to_plot:
        ## maximum likelihood
        p=data[:i].mean() ## estimated ctr
        n=i+1 ## num of samples collected so far
        std=np.sqrt(p*(1-p)/n)
        ## normal
        x=np.linspace(0,1,200)
        g=norm.pdf(x,loc=p,scale=std)
        plt.plot(x, g, label='Gaussian Approximation')

        ## beta
        d=beta.pdf(x,a=a,b=b)
        plt.plot(x, d, label='beta Approximation')

        plt.legend()
        plt.title("N = %s" % n)
        plt.show()
